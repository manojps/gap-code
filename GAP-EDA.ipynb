# %%
import re
import pandas as pd
import spacy
from spacy.symbols import PROPN, PERSON
from __future__ import unicode_literals, print_function

# %%
nlp = spacy.load('en_core_web_sm')

# %% [markdown]
# Read training, validation and test data.

# %%
# Read training, validation and test data.
train = pd.read_csv('..\gap-coreference\gap-development.tsv', sep='\t')
valid = pd.read_csv('..\gap-coreference\gap-validation.tsv', sep='\t')
test = pd.read_csv('..\gap-coreference\gap-test.tsv', sep='\t')

# %%
def sample_count(df):
    ''' 
    Get number of samples in each set. 
    
    :param df: A Pandas dataframe
    :type df: pandas.core.frame.DataFrame
    :return: Numer of rows in dataframe 
    :rtype: int
    '''
    return df.shape[0]


def feature_names(df):
    ''' 
    Get names of features. 
    
    :param df: A Pandas dataframe
    :type df: pandas.core.frame.DataFrame
    :return: List of column names in a Pandas dataframe
    :rtype: numpy.ndarray
    '''
    return df.columns.values


def column_value_counts(df, target_column, new_column):
    '''
    Get value counts of each categorical variable. Store this data in 
    a dataframe. Also add a column with relative percentage of each 
    categorical variable.
    
    :param df: A Pandas dataframe
    :param target_column: Name of the column in the original dataframe (string)
    :param new_column: Name of the new column where the frequency counts are stored 
    :type df: pandas.core.frame.DataFrame
    :type target_column: str
    :type new_column: str
    :return: A Pandas dataframe containing the frequency counts
    :rtype: pandas.core.frame.DataFrame
    '''
    df_value_counts = df[target_column].value_counts()
    df = pd.DataFrame(df_value_counts)
    df.columns = [new_column]
    df[new_column+'_%'] = 100*df[new_column] / df[new_column].sum()
    return df


def create_labels(df):
    '''
    Create labels of which candidate reference is the correct one, if any. 
    Store the labels in a new column in the dataframe. 
    
    :param df: A Pandas dataframe
    :type df: pandas.core.frame.DataFrame
    :return: Returns the updated Pandas dataframe
    :rtype: pandas.core.frame.DataFrame
    '''
    df['labels'] = 'Neither'
    df.loc[df['A-coref'] == True, 'labels'] = 'A'
    df.loc[df['B-coref'] == True, 'labels'] = 'B'
    return df


def pronouns(df):
    ''' 
    Get a list of all unique pronouns in the dataset. 
    
    :param df: A Pandas dataframe
    :type df: pandas.core.frame.DataFrame
    :return: List of dataframe indexes 
    :rtype: numpy.ndarray
    '''
    return df.index.tolist()


def count_all_pronoun(text):
    ''' 
    Count all pronouns in passed text.
    
    :param text: A string
    :type text: str
    :return: Number of pronouns in the text string
    :rtype: int
    '''
    return len(re.findall(r"\b(He|Her|His|She|he|her|hers|him|his|she)\b", text))


def store_pronoun_count(df):
    ''' 
    Count all pronouns in each row and store it in a new column named "Pronoun-count". 
    
    :param df: A Pandas dataframe
    :type df: pandas.core.frame.DataFrame
    :return: Returns nothing
    :rtype: None
    '''
    df['Pronoun-count'] = df['Text'].apply(count_all_pronoun)
    return
    
def text_len(df):
    ''' 
    Count text length in each row and stroe it in a new column named "Text-len". 
    
    :param df: A Pandas dataframe
    :type df: pandas.core.frame.DataFrame
    :return: Returns nothing
    :rtype: None
    '''
    df['Text-len'] = df.Text.str.len()
    return

def column_summary(df, target_column, new_column):
    ''' 
    Compute column summary and return as a dataframe. 
    
    :param df: A Pandas dataframe
    :param target_column: Name of the column in the original dataframe (string)
    :param new_column: Name of the new column where the frequency counts are stored 
    :type df: pandas.core.frame.DataFrame
    :type target_column: str
    :type new_column: str
    :return: A Pandas dataframe containing the summary
    :rtype: pandas.core.frame.DataFrame
    '''
    temp = pd.DataFrame(df[target_column].describe())
    temp.columns = [new_column]
    temp = temp.round(2)
    return temp

def word_count(df):
    ''' 
    Count and store words in "Text" for each row of the dataframe. 
    
    :param df: A Pandas dataframe
    :type df: pandas.core.frame.DataFrame
    :return: Returns nothing
    :rtype: None
    '''
    df['Word-count'] = df.Text.str.split().str.len()
    return
    
def person_entity_count(text):
    ''' 
    Extract person names and count the number of person name occurences. 
    Not completely accurate. 
    
    :param text: Text sample in the dataset
    :type text: str
    :return: Rturns the number of person names in the text
    :rtype: int
    '''
    doc = nlp(text)
    p_count = 0
    #person = []
    for ent in doc.ents:
        if ent.label == PERSON:
            p_count += 1
            #person.append(ent.text)
    return p_count

def pronoun_capital(pronoun_text):
    '''
    Find if the passed pronoun starts with a capital letter.
    
    :param pronoun_text: The target pronoun
    :type pronoun_text: str
    :return: Returns true or false
    :rtype: int
    '''
    z = re.match('(H\w+)', pronoun_text)
    if z is None:
        return 0
    else:
        return 1

def pronoun_first_word(df):
    '''
    Find if the target pronoun is the frst word in the sentence, and store it in a 
    column in the dataframe.
    
    :param df: A Pandas dataframe
    :type df: pandas.core.frame.DataFrame
    :return: Returns nothing
    :rtype: None
    '''
    df['Pronoun-first-word'] = df['Text'].apply(pronoun_capital)
    return

# %%
print(" Training set: {} \n Validation set: {} \n Test Set: {}\n".
      format(sample_count(train), sample_count(valid), sample_count(test)))

print("Feature names: {}".format(feature_names(train)))
# Out:
#  Training set: 2000
#  Validation set: 454
#  Test Set: 2000
#
# Feature names: ['ID' 'Text' 'Pronoun' 'Pronoun-offset' 'A' 'A-offset' 'A-coref' 'B'
#  'B-offset' 'B-coref' 'URL']

# %%
train.head()
# Out:
#               ID                                               Text Pronoun  \
# 0  development-1  Zoe Telford -- played the police officer girlf...     her
# 1  development-2  He grew up in Evanston, Illinois the second ol...     His
# 2  development-3  He had been reelected to Congress, but resigne...     his
# 3  development-4  The current members of Crime have also perform...     his
# 4  development-5  Her Santa Fe Opera debut in 2005 was as Nuria ...     She
#
#    Pronoun-offset                  A  A-offset  A-coref                B  \
# 0             274     Cheryl Cassidy       191     True          Pauline
# 1             284          MacKenzie       228     True    Bernard Leach
# 2             265            Angeloz       173    False       De la Sota
# 3             321               Hell       174    False  Henry Rosenthal
# 4             437  Kitty Oppenheimer       219    False           Rivera
#
#    B-offset  B-coref        ...        Pronoun-count  Text-len  Word-count  \
# 0       207    False        ...                    6       426          74
# 1       251    False        ...                    4       410          65
# 2       246     True        ...                    2       536          95
# 3       336     True        ...                    1       401          69
# 4       294     True        ...                    4       660         112
#
#    Person-name-count  Pronoun-first-word  A-pronoun-offset-diff  \
# 0                 11                   0                    -83
# 1                  7                   1                    -56
# 2                  2                   1                    -92
# 3                  4                   0                   -147
# 4                  7                   1                   -218
#
#    B-pronoun-offset-diff  Pronoun-sentence-number A-sentence-number  \
# 0                    -67                        3                 2
# 1                    -33                        3                 2
# 2                    -19                        3                 2
# 3                     15                        2                 1
# 4                   -143                        3                 2
#
#   B-sentence-number
# 0                 2
# 1                 2
# 2                 2
# 3                 2
# 4                 2
#
# [5 rows x 21 columns]

# %%
# Get frequency distribution of pronouns in each set
df_train = column_value_counts(train, 'Pronoun', 'Train')
df_test = column_value_counts(test, 'Pronoun', 'Test')
df_valid = column_value_counts(valid, 'Pronoun', 'Validation')

pronoun_count = pd.concat([df_train, df_valid, df_test], axis=1) # Merge dataframes by index
pronoun_count = pronoun_count.fillna(0) # Replace Nan with 0 (zero)
pronoun_count = pronoun_count.round(2) # Rounding decimals to two digits after .
print(pronoun_count.sort_values(by=['Train'], ascending=False))
# Out:
#       Train  Train_%  Validation  Validation_%  Test  Test_%
# her   534.0    26.70       132.0         29.07   566   28.30
# his   496.0    24.80       102.0         22.47   528   26.40
# she   249.0    12.45        62.0         13.66   237   11.85
# he    235.0    11.75        67.0         14.76   221   11.05
# She   179.0     8.95        25.0          5.51   159    7.95
# He    138.0     6.90        26.0          5.73   127    6.35
# him    98.0     4.90        26.0          5.73    96    4.80
# Her    38.0     1.90         8.0          1.76    37    1.85
# His    33.0     1.65         6.0          1.32    28    1.40
# hers    0.0     0.00         0.0          0.00     1    0.05

# %%
# Get frequency distribution of which candidate noun is correct in each set
train = create_labels(train)
test = create_labels(test)
valid = create_labels(valid)

df_train = column_value_counts(train, 'labels', 'Train_lables')
df_test = column_value_counts(test, 'labels', 'Test_labels')
df_valid = column_value_counts(valid, 'labels', 'Validation_labels')

label_count = pd.concat([df_train, df_valid, df_test], axis=1)
label_count = label_count.round(2)
label_count.head()
# Out:
#          Train_lables  Train_lables_%  Validation_labels  Validation_labels_%  \
# A                 874           43.70                187                41.19
# B                 925           46.25                205                45.15
# Neither           201           10.05                 62                13.66
#
#          Test_labels  Test_labels_%
# A                918          45.90
# B                855          42.75
# Neither          227          11.35

# %%
# Get all unique pronouns in text
unique_pronouns = pronouns(pronoun_count)
print(unique_pronouns)
# Out:
# ['He', 'Her', 'His', 'She', 'he', 'her', 'hers', 'him', 'his', 'she']

# %%
# Get text length and store it in a new column
text_len(train)
text_len(valid)
text_len(test)

# %%
# Get summary of text length and compare side by side
df_train = column_summary(train, 'Text-len', 'Train')
df_test = column_summary(test, 'Text-len', 'Test')
df_valid = column_summary(valid, 'Text-len', 'Validation')

text_length_summary = pd.concat([df_train, df_valid, df_test], axis=1)
print(text_length_summary)
# Out:
#          Train  Validation     Test
# count  2000.00      454.00  2000.00
# mean    426.92      426.39   430.61
# std     124.63      112.64   130.72
# min     104.00      147.00    69.00
# 25%     346.00      354.00   344.00
# 50%     410.00      408.50   412.00
# 75%     493.00      487.75   500.00
# max    1270.00     1012.00  1347.00

# %%
# Get pronoun count in text and store it in a new column
store_pronoun_count(train)
store_pronoun_count(valid)
store_pronoun_count(test)

# Get summary of pronoun count and compare side by side
df_train = column_summary(train, 'Pronoun-count', 'Train')
df_test = column_summary(test, 'Pronoun-count', 'Test')
df_valid = column_summary(valid, 'Pronoun-count', 'Validation')

pronoun_count_summary = pd.concat([df_train, df_valid, df_test], axis=1)
print(pronoun_count_summary)
# Out:
#          Train  Validation     Test
# count  2000.00      454.00  2000.00
# mean      3.11        3.39     3.03
# std       2.06        2.36     2.00
# min       1.00        1.00     1.00
# 25%       2.00        2.00     2.00
# 50%       3.00        3.00     3.00
# 75%       4.00        5.00     4.00
# max      17.00       16.00    15.00

# %%
# Get word count in each row
word_count(train)
word_count(valid)
word_count(test)

# Get summary of word count and compare side by side
df_train = column_summary(train, 'Word-count', 'Train')
df_test = column_summary(test, 'Word-count', 'Test')
df_valid = column_summary(valid, 'Word-count', 'Validation')

word_count_summary = pd.concat([df_train, df_valid, df_test], axis=1)
print(word_count_summary)
# Out:
#          Train  Validation     Test
# count  2000.00      454.00  2000.00
# mean     71.20       70.95    71.58
# std      20.53       18.64    20.94
# min      16.00       20.00    12.00
# 25%      58.00       59.00    58.00
# 50%      68.00       69.00    69.00
# 75%      82.00       80.00    83.00
# max     204.00      187.00   223.00

# %%
# Get count of person names in the text and store in a column
train['Person-name-count'] = train['Text'].apply(person_entity_count)
test['Person-name-count'] = test['Text'].apply(person_entity_count)
valid['Person-name-count'] = valid['Text'].apply(person_entity_count)

# Get summary of person name count and compare side by side
df_train = column_summary(train, 'Person-name-count', 'Train')
df_test = column_summary(test, 'Person-name-count', 'Test')
df_valid = column_summary(valid, 'Person-name-count', 'Validation')
person_name_count_summary = pd.concat([df_train, df_valid, df_test], axis=1)
print(person_name_count_summary)
# Out:
#          Train  Validation     Test
# count  2000.00      454.00  2000.00
# mean      4.55        4.91     4.48
# std       2.68        3.05     2.81
# min       0.00        0.00     0.00
# 25%       3.00        3.00     3.00
# 50%       4.00        4.00     4.00
# 75%       6.00        6.00     6.00
# max      23.00       20.00    30.00

# %%
# Number of target pronouns that are the first word in the sentence
pronoun_first_word(train)
pronoun_first_word(valid)
pronoun_first_word(test)
print("Training set: {}".format(train['Pronoun-first-word'].sum()))
print("Validation set: {}".format(valid['Pronoun-first-word'].sum()))
print("Test set {}".format(test['Pronoun-first-word'].sum()))
# Out:
# Training set: 223
# Validation set: 45
# Test set 222

# %%
# Any relation of candidate A and B with pronoun is first word or not?
def first_coref_relation(df):
    first_a, first_b, not_first_a, not_first_b = 0, 0, 0, 0

    for i, p in enumerate(df['Pronoun-first-word']):
        if p == 0:
            if df['A-coref'].iloc[i] == True:
                not_first_a += 1
            elif df['B-coref'].iloc[i] == True:
                not_first_b += 1
        else:
            if df['A-coref'].iloc[i] == True:
                first_a += 1
            elif df['B-coref'].iloc[i] == True:
                first_b += 1     
    
    return first_a, first_b, not_first_a, not_first_b

print(first_coref_relation(train))
print(first_coref_relation(valid))
print(first_coref_relation(test))
# Out:
# (105, 98, 769, 827)
# (20, 19, 167, 186)
# (112, 88, 806, 767)

# %%
# In how many cases the candiate name appears after the target pronoun?
a = (train['A-offset'] - train['Pronoun-offset']) > 0
b = (train['B-offset'] - train['Pronoun-offset']) > 0
print(sum(a == True), sum(b == True))
#print(sum(a == False), sum(b == False))
# Out:
# 274 496

# %%
# Calculate the offset difference between the pronoun and the candidate names
def diff_pronoun_noun_offset(df, name_column):
    df[name_column[0]+'-pronoun-offset-diff'] = (df[name_column] - df['Pronoun-offset'])
    return

diff_pronoun_noun_offset(train, 'A-offset')
diff_pronoun_noun_offset(train, 'B-offset')
diff_pronoun_noun_offset(valid, 'A-offset')
diff_pronoun_noun_offset(valid, 'B-offset')
diff_pronoun_noun_offset(test, 'A-offset')
diff_pronoun_noun_offset(test, 'B-offset')

# %%
# How close are the target nouns and pronouns?
df_train_A = column_summary(train, 'A-pronoun-offset-diff', 'Train-A')
df_train_B = column_summary(train, 'B-pronoun-offset-diff', 'Train-B')
df_valid_A = column_summary(train, 'A-pronoun-offset-diff', 'Validation-A')
df_valid_B = column_summary(train, 'B-pronoun-offset-diff', 'Validation-B')
df_test_A = column_summary(train, 'A-pronoun-offset-diff', 'Test-A')
df_test_B = column_summary(train, 'B-pronoun-offset-diff', 'Test-B')

pronoun_offset_diff_summary = pd.concat([df_train_A, df_train_B, df_valid_A, 
                                       df_valid_B, df_test_A, df_test_B], axis=1)
print(pronoun_offset_diff_summary)
# Out:
#        Train-A  Train-B  Validation-A  Validation-B   Test-A   Test-B
# count  2000.00  2000.00       2000.00       2000.00  2000.00  2000.00
# mean    -85.19   -24.43        -85.19        -24.43   -85.19   -24.43
# std      77.35    71.07         77.35         71.07    77.35    71.07
# min    -577.00  -461.00       -577.00       -461.00  -577.00  -461.00
# 25%    -126.00   -58.00       -126.00        -58.00  -126.00   -58.00
# 50%     -82.00   -28.00        -82.00        -28.00   -82.00   -28.00
# 75%     -45.00    -5.75        -45.00         -5.75   -45.00    -5.75
# max     280.00   291.00        280.00        291.00   280.00   291.00

# %%
# Get the rows where candiate A appears after pronoun, but is still the True coreference
train.loc[((train['A-pronoun-offset-diff'] > 0) == True) & (train['A-coref'] == True)]
# Out:
#                     ID                                               Text  \
# 21      development-22  This device allowed him to continue his racing...
# 27      development-28  This is a list of episodes from the MTV show B...
# 73      development-74  He is currently the wide receivers coach for B...
# 85      development-86  The musical style is essentially tonal, evokin...
# 103    development-104  His work as an arranger, producer and songwrit...
# 119    development-120  Oliveira would take a major step forward with ...
# 131    development-132  Then he persuades future son-in-law Ben to bet...
# 135    development-136  Miller is also currently serving as the produc...
# 140    development-141  Isabel Walker is a twenty-something American f...
# 145    development-146  Rocky intervenes, and after seemingly beating ...
# 152    development-153  The administration of Jewish communal affairs ...
# 185    development-186  For her artist days, Parol cited artists such ...
# 195    development-196  Lewis Hamilton went past Romain Grosjean for s...
# 218    development-219  On 27 September 2014, Toshney signed for Ross ...
# 238    development-239  Crummell was raised in the town of Gander in c...
# 241    development-242  He has barely entered the door to the office b...
# 263    development-264  The offering, though Isaac does not know this,...
# 265    development-266  As early as the age of six, he began watching ...
# 273    development-274  The first caution came out on lap 9 when Aric ...
# 277    development-278  The four-second fall from the Golden Gate Brid...
# 332    development-333  Challenge of the Masters (Chinese: *******) is...
# 338    development-339  One of his works praises the city of Benghazi....
# 344    development-345  At the Battle of Arausio, Caepio refused to co...
# 371      she             349                Christy       389     True
# 390      his             185                  Dimon       226     True
# 391      his             343                  Byron       364     True
# 413      her             264                  Tilly       281     True
# 423      his             379  Alexandru Hrisoverghi       412     True
# 483      his             307                  Zhang       342     True
# 487      his             382            Montesquiou       402     True
# ...      ...             ...                    ...       ...      ...
# 1453     his             374                Corchia       406     True
# 1465     his             280                  Crewe       312     True
# 1508     his             338     James Forbes Smith       372     True
# 1512      he             286              Skywalker       310     True
# 1524     his             257                  Catan       282     True
# 1529     his              84     Napoleon Bonaparte       158     True
# 1530     his             386                  Bruce       398     True
# 1539     his             289                   Raju       302     True
# 1547     his             356                 Chiang       376     True
# 1550     her             169                Jessica       179     True
# 1567     his             340                 Osborn       411     True
# 1595      he             513              Rebennack       546     True
# 1652     her             282                 Angela       295     True
# 1660     she             222                    Eve       270     True
# 1693     her             443                  Kurys       459     True
# 1709     her             313            Judy Jacobs       386     True
# 1722     her             295                   Rita       306     True
# 1734     her             294               Winspear       308     True
# 1772     her             158                 Jarosz       175     True
# 1773     her               6                Sobotka        61     True
# 1774     her             167                  Oller       200     True
# 1839     she             286            Cecily Pine       299     True
# 1849     her             416                 Hannah       441     True
# 1863     her             240                 Melina       270     True
# 1874     her             269                Gillard       302     True
# 1890     her             348                Mauceri       370     True
# 1908     her             286              Glasscock       331     True
# 1969     her             445                  Emily       458     True
# 1987     her              18                 Alison        37     True
# 1992     her             316                  Jenny       343     True
#
#                        B  B-offset  B-coref  \
# 21           Paul Newman       338    False
# 27                  Ryan       223    False
# 73       Jim Ned Indians       449    False
# 85          Charles Ives       439    False
# 103            Paul Anka       319    False
# 119         Otis Griffin       368    False
# 131                  Ben       266    False
# 135      Joseph P. Hayes       449    False
# 140               Isabel       429    False
# 145   Supriya Pilgaonkar       526    False
# 152                  God       491    False
# 185       Shirley Manson        49    False
# 195         Ayrton Senna       445    False
# 218              Toshney       447    False
# 238            Executive       320    False
# 241                  Mat       361    False
# 263                Isaac       330    False
# 265                Apter       702    False
# 273            Earnhardt       381    False
# 277          Ken Baldwin       517    False
# 332        Chen Kuan Tai       321    False
# 338              Gaddafi       277    False
# 344               Caepio       319    False
# 371   Catherine Marshall       400    False
# 390               Butler       266    False
# 391               Giraud       383    False
# 413          Peggy Fuery       366    False
# 423              Ch*nier       465    False
# 483                Huang       377    False
# 487    St*phane Mallarm*       423    False
# ...                  ...       ...      ...
# 1453             Le Mans       421    False
# 1465         Ben E. King       400    False
# 1508             Fairlie       479    False
# 1512              Kenobi       324    False
# 1524   Stephen the Great       345    False
# 1529             Emperor       301    False
# 1530             Vincent       434    False
# 1539         Sanjay Dutt       375    False
# 1547        Leon Trotsky       387    False
# 1550    Layla Williamson       244    False
# 1567               Stark       467    False
# 1595  Professor Longhair       560    False
# 1652                Ruth       313    False
# 1660                 Fox       376    False
# 1693      Penny Marshall       543    False
# 1709             Yatauro       436    False
# 1722  Princess Theophane       334    False
# 1734        Maisie Dobbs       340    False
# 1772       268          44                  6                   0
# 1773       244          37                  2                   0
# 1774       399          68                  6                   0
# 1839       382          61                  3                   0
# 1849       563          98                  5                   0
# 1863       339          60                  3                   0
# 1874       434          69                  3                   0
# 1890       503          90                  5                   0
# 1908       406          61                  6                   0
# 1969       535          93                  2                   0
# 1987       262          45                  4                   0
# 1992       497          86                  6                   0
#
#       A-pronoun-offset-diff  B-pronoun-offset-diff
# 21                       13                     34
# 27                       10                     29
# 73                       27                    174
# 85                       20                     54
# 103                       9                     79
# 119                      21                     39
# 131                      12                     36
# 135                      31                    126
# 140                      13                     33
# 145                      71                     96
# 152                      46                    158
# 185                      17                     45
# 195                      61                     76
# 218                      84                    131
# 238                      17                     40
# 241                      15                     40
# 263                      47                     65
# 265                     132                    267
# 273                      22                     42
# 277                      32                    140
# 332                      79                    121
# 338                      13                     61
# 344                      34                    109
# 371                      40                     51
# 390                      41                     81
# 391                      21                     40
# 413                      17                    102
# 423                      33                     86
# 483                      35                     70
# 487                      20                     41
# ...                     ...                    ...
# 1453                     32                     47
# 1465                     32                    120
# 1508                     34                    141
# 1512                     24                     38
# 1524                     25                     88
# 1529                     74                    217
# 1530                     12                     48
# 1539                     13                     86
# 1547                     20                     31
# 1550                     10                     75
# 1567                     71                    127
# 1595                     33                     47
# 1652                     13                     31
# 1660                     48                    154
# 1693                     16                    100
# 1709                     73                    123
# 1722                     11                     39
# 1734                     14                     46
# 1772                     17                     70
# 1773                     55                    182
# 1774                     33                    194
# 1839                     13                     34
# 1849                     25                    132
# 1863                     30                     57
# 1874                     33                     80
# 1890                     22                     83
# 1908                     45                     68
# 1969                     13                     72
# 1987                     19                     83
# 1992                     27                     56
#
# [123 rows x 18 columns]

# %%
# Get the rwos where candiate B appears after pronoun, but is still the True coreference
train.loc[((train['B-pronoun-offset-diff'] > 0) == True) & (train['B-coref'] == True)]
# Out:
#                     ID                                               Text  \
# 3        development-4  The current members of Crime have also perform...
# 7        development-8  Slant Magazine's Sal Cinquemani viewed the alb...
# 8        development-9  Her father was an Englishman ``of rank and cul...
# 42      development-43  Impressed by her beauty, her warrior skills, a...
# 52      development-53  In 1972, Henning broke the world records on th...
# 56      development-57  Classicist John H. D'Arms was both the residen...
# 79      development-80  In 1984, Petersen married Zina Nibley, a daugh...
# 96      development-97  Caswell begins to doubt that it was Bullard wh...
# 102    development-103  Donald P. Kanak is non-executive Chairman of P...
# 113    development-114  He informs Blackadder and Baldrick, ``For us, ...
# 118    development-119  Heightened political pressure and illness push...
# 120    development-121  The series was recorded in front of a live aud...
# 134    development-135  The leader of the Legnano--Pirelli team, Grazi...
# 156    development-157  As tempting as it can be to think of Liszt as ...
# 161    development-162  Henry Wallis (1830--1916) was an English Pre-R...
# 164    development-165  In 1854, in order to live less expensively, So...
# 171    development-172  He sold off the boy's brothers and sisters in ...
# 176    development-177  The organization of the household was so effic...
# 187    development-188  Attempting to drown his sorrows, Peter visits ...
# 164      her             394            Carolyn Sawyer       439    False
# 171       he             332                    Hayden       227    False
# 176       he             351      Aleksey Mikhailovich       237    False
# 187       he             319                    Horace       328    False
# 208      his             178                  Ferguson       198    False
# 213      his             293                Ben London       306    False
# 219      his             272                 Gillespie       203    False
# 229      his             343         Paul Pellisson.Il       379    False
# 231       he             248                      King       322    False
# 235      her             315                 Elizabeth       335    False
# 247      his             407                   Haggard       231    False
# 261      his             268        Current Generation       297    False
# 266      her               3           Haythornthwaite        33    False
# 274      her             558                     Marge       838    False
# 278      her             266                    Rinker       205    False
# ...      ...             ...                       ...       ...      ...
# 1696     her             329                     Vicki       287    False
# 1698     her             406            Sadhana Sargam       384    False
# 1707     her             153            Betty Anderson       176    False
# 1708     her             329         Iroda Tulyaganova       261    False
# 1713     her             316                   Frankel       300    False
# 1724     her             204           Sheila Burnford       215    False
# 1748     She             244              Jane Siberry       230    False
# 1759     her             345                   Shirley       178    False
# 1794     her             240  Mildred Loving in Loving       257    False
# 1797     her             406                  Mary Sue       279    False
# 1798     she             325          Mary Tyler Moore       345    False
# 1815     her             114              Kay Thompson        97    False
# 1817     her             251           Victoria Spivey       169    False
# 1820     her             347      Duchess of Cambridge       317    False
# 1827     her             233                    Granny       254    False
# 1842     her             318            Crown Princess       296    False
# 1847     her             318          Eleanor Simmonds       278    False
# 1851     her             377       Althea Brooks Small       389    False
# 1852     her             313              Emma Willard       281    False
# 1855     her             310               Mary Walker       322    False
# 1882     her             303                     Ellen       257    False
# 1898     she             335                   Queenie       369    False
# 1900     her              13        Tatyana Vladimovna        25    False
# 1924     her             364             Joan Fontaine       379    False
# 1940     her             307              Laura Harvey       331    False
# 1955     her             382        Jacqueline Kennedy       327    False
# 1958     she              15                       Fey        30    False
# 1963     her             238              Emily Kmetko       217    False
# 1965     her             280                  Wormwood       351    False
# 1973     her             188                      Leah       130    False
#
#                            B  B-offset  B-coref  \
# 3            Henry Rosenthal       336     True
# 7           Robert Christgau       377     True
# 8                     Kelsey       267     True
# 42                     Nyssa       355     True
# 52                   Henning       221     True
# 56    Adele Chatfield-Taylor       331     True
# 79                  Petersen       354     True
# 96                   Bullard       448     True
# 102                    Kanak       300     True
# 113               Richthofen       359     True
# 118                  Madrazo       432     True
# 120              Spike Dixon       406     True
# 134               Battistini       229     True
# 156                    Liszt       524     True
# 161                    Henry       266     True
# 164                    Soule       465     True
# 171     Marquis de Lafayette       382     True
# 176          Peter the Great       367     True
# 187                    Peter       360     True
# 208                    Giggs       220     True
# 213                      Vic       334     True
# 219                     Byas       296     True
# 229            Father Boisot       460     True
# 231            Father Joseph       332     True
# 235                   Isabel       428     True
# 247           David Cantwell       452     True
# 261           Brother Saylor       343     True
# 266              Nora Wright       135     True
# 274                     Lisa       849     True
# 278                   Bailey       301     True
# ...                      ...       ...      ...
# 1696                Michelle       334     True
# 1698                  Kavita       485     True
# 1707               Catherine       192     True
# 1708             Shaughnessy       356     True
# 1713                Richards       325     True
# 1724                    Ross       315     True
# 1748                  Deanna       355     True
# 1759                   Carly       362     True
# 1794                   Negga       290     True
# 1797     Camille Bacon-Smith       435     True
# 1798                  Peters       363     True
# 1815                  Eloise       128     True
# 1817                     Cox       296     True
# 1820                    Anne       359     True
# 1827                    Ryan       320     True
# 1842                   Paget       355     True
# 1847                  Robson       330     True
# 1851             Nona Brooks       410     True
# 1852                  Phelps       325     True
# 1855                 Johnson       370     True
# 1882             Bertha Benz       370     True
# 1898                   Fiona       378     True
# 1900                 Demkina        45     True
# 1924                  Olivia       431     True
# 1940                   Megan       352     True
# 1955                  Crespi       419     True
# 1958             Sarah Palin        47     True
# 1963                   Hobbs       249     True
# 1965                 Matilda       397     True
# 1973                  Brooke       200     True
#
#                                                     URL  Pronoun-count  \
# 3             http://en.wikipedia.org/wiki/Crime_(band)              1
# 7     http://en.wikipedia.org/wiki/The_Truth_About_L...              1
# 8            http://en.wikipedia.org/wiki/Mary_S._Peake              5
# 42            http://en.wikipedia.org/wiki/Nyssa_Raatko             14
# 52            http://en.wikipedia.org/wiki/Anne_Henning              3
# 56    http://en.wikipedia.org/wiki/American_Academy_...              1
# 79           http://en.wikipedia.org/wiki/Boyd_Petersen              2
# 96         http://en.wikipedia.org/wiki/Executive_Suite              5
# 102        http://en.wikipedia.org/wiki/Donald_P._Kanak              2
# 113   http://en.wikipedia.org/wiki/The_Red_Baron_in_...              3
# 118   http://en.wikipedia.org/wiki/Elba_Esther_Gordillo              4
# 120   http://en.wikipedia.org/wiki/The_Newly_Discove...              1
# 134   http://en.wikipedia.org/wiki/List_of_teams_and...              3
# 156   http://en.wikipedia.org/wiki/Late_works_of_Fra...              6
# 161           http://en.wikipedia.org/wiki/Henry_Wallis              3
# 164         http://en.wikipedia.org/wiki/Caroline_Soule              2
# 171           http://en.wikipedia.org/wiki/Lewis_Hayden              6
# 176       http://en.wikipedia.org/wiki/Izmaylovsky_Park              3
# 187   http://en.wikipedia.org/wiki/Blind_Ambition_(F...              5
# 208             http://en.wikipedia.org/wiki/Ryan_Giggs              3
# 213           http://en.wikipedia.org/wiki/Mad_Dog_Time              1
# 219               http://en.wikipedia.org/wiki/Don_Byas              3
# 229   http://en.wikipedia.org/wiki/Jean-Baptiste_Boisot              1
# 231      http://en.wikipedia.org/wiki/Cinq-Mars_(opera)              5
# 235   http://en.wikipedia.org/wiki/Isabel_le_Despens...              8
# 247         http://en.wikipedia.org/wiki/Ramblin'_Fever              2
# 261        http://en.wikipedia.org/wiki/Sigma_Alpha_Rho              1
# 266   http://en.wikipedia.org/wiki/Caroline_Haythorn...              1
# 274   http://en.wikipedia.org/wiki/Smoke_on_the_Daug...             13
# 278         http://en.wikipedia.org/wiki/Mildred_Bailey              4
# ...                                                 ...            ...
# 1696             http://en.wikipedia.org/wiki/Den_Watts              6
# 1698  http://en.wikipedia.org/wiki/Kavita_Krishnamurthy              6
# 1707  http://en.wikipedia.org/wiki/Catherine_Harrington              5
# 1708   http://en.wikipedia.org/wiki/Meghann_Shaughnessy              6
# 1713  http://en.wikipedia.org/wiki/The_Real_Housewiv...              4
# 1724   http://en.wikipedia.org/wiki/Susan_Ross_(artist)              4
# 1748           http://en.wikipedia.org/wiki/Deanna_Kirk              4
# 1759           http://en.wikipedia.org/wiki/Carly_Wicks              3
# 1794            http://en.wikipedia.org/wiki/Ruth_Negga              3
# 1797              http://en.wikipedia.org/wiki/Mary_Sue              1
# 1798     http://en.wikipedia.org/wiki/Bernadette_Peters              2
# 1815  http://en.wikipedia.org/wiki/Eloise:_The_Anima...              2
# 1817               http://en.wikipedia.org/wiki/Ida_Cox              3
# 1820        http://en.wikipedia.org/wiki/Anne_Gascoigne              5
# 1827            http://en.wikipedia.org/wiki/Irene_Ryan              2
# 1842  http://en.wikipedia.org/wiki/Walburga,_Lady_Paget              2
# 1847          http://en.wikipedia.org/wiki/Laura_Robson              6
# 1851        http://en.wikipedia.org/wiki/Nona_L._Brooks              4
# 1852  http://en.wikipedia.org/wiki/Almira_Hart_Linco...              5
# 1855         http://en.wikipedia.org/wiki/Belle_Johnson              5
# 1882           http://en.wikipedia.org/wiki/Bertha_Benz              3
# 1898  http://en.wikipedia.org/wiki/The_Replacements_...              8
# 1900       http://en.wikipedia.org/wiki/Natasha_Demkina              3
# 1924   http://en.wikipedia.org/wiki/Olivia_de_Havilland              4
# 1940         http://en.wikipedia.org/wiki/Megan_Brigman              3
# 1955       http://en.wikipedia.org/wiki/Consuelo_Crespi              4
# 1958  http://en.wikipedia.org/wiki/Saturday_Night_Li...              1
# 1963         http://en.wikipedia.org/wiki/Chelsea_Hobbs              2
# 1965      http://en.wikipedia.org/wiki/Matilda_Wormwood              6
# 1973   http://en.wikipedia.org/wiki/Brooke_Barrettsmith              3
#
#       Text-len  Word-count  Person-name-count  Pronoun-first-word  \
# 3          401          69                  4                   0
# 7          451          71                  4                   0
# 8          302          53                  3                   1
# 42         522          87                  3                   0
# 52         338          59                  2                   0
# 56         528          85                  3                   0
# 79         403          65                  6                   0
# 96         513          86                  1                   0
# 102        368          56                  3                   0
# 113        429          66                  4                   1
# 118        553          89                  2                   1
# 120        504          87                  6                   0
# 134        279          46                  5                   0
# 156        626         103                  0                   0
# 161        302          45                  4                   1
# 164        497          78                  6                   0
# 171        537          89                  1                   1
# 176        504          88                  2                   0
# 187        427          73                  4                   0
# 208        317          55                  5                   0
# 213        501          84                  6                   0
# 219        347          56                  2                   0
# 229        592          98                  5                   0
# 231        423          69                  6                   0
# 235        502          81                  2                   0
# 247        829         129                  6                   1
# 261        495          92                  5                   0
# 266        309          46                  1                   0
# 274        989         180                  6                   1
# 278        391          66                  4                   0
# ...        ...         ...                ...                 ...
# 1696       442          85                  5                   0
# 1698       549          87                 13                   0
# 1707       248          44                  8                   0
# 1708       546          95                  1                   0
# 1713       432          69                 10                   0
# 1724       432          71                  3                   0
# 1748       519          85                  3                   0
# 1759       458          78                  6                   0
# 1794       549          92                  4                   0
# 1797       553          83                  3                   0
# 1798       432          69                  5                   0
# 1815       186          33                  2                   0
# 1817       459          73                  8                   0
# 1820       393          66                  6                   0
# 1827       349          57                  4                   0
# 1842       497          75                  7                   0
# 1847       415          71                  1                   0
# 1851       503          84                  4                   0
# 1852       446          73                  4                   0
# 1855       450          74                  6                   0
# 1882       606          92                  5                   0
# 1898       466          82                 10                   0
# 1900       186          32                  1                   0
# 1924       453          73                  2                   0
# 1940       458          81                  2                   0
# 1955       543          94                  6                   0
# 1958       147          26                  2                   0
# 1963       365          66                  4                   0
# 1965       474          79                  5                   0
# 1973       243          38                  3                   0
#
#       A-pronoun-offset-diff  B-pronoun-offset-diff
# 3                      -147                     15
# 7                      -164                     40
# 8                         9                     21
# 42                       11                     18
# 52                       23                     55
# 56                     -104                     44
# 79                       29                     42
# 96                       46                     91
# 102                     -39                     37
# 113                     -71                     24
# 118                      42                     72
# 120                    -170                     12
# 134                      45                     59
# 156                     -11                     16
# 161                      38                     84
# 164                      45                     71
# 171                    -105                     50
# 176                    -114                     16
# 187                       9                     41
# 208                      20                     42
# 213                      13                     41
# 219                     -69                     24
# 229                      36                    117
# 231                      74                     84
# 235                      20                    113
# 247                    -176                     45
# 261                      29                     75
# 266                      30                    132
# 274                     280                    291
# 278                     -61                     35
# ...                     ...                    ...
# 1696                    -42                      5
# 1698                    -22                     79
# 1707                     23                     39
# 1708                    -68                     27
# 1713                    -16                      9
# 1724                     11                    111
# 1748                    -14                    111
# 1759                   -167                     17
# 1794                     17                     50
# 1797                   -127                     29
# 1798                     20                     38
# 1815                    -17                     14
# 1817                    -82                     45
# 1820                    -30                     12
# 1827                     21                     87
# 1842                    -22                     37
# 1847                    -40                     12
# 1851                     12                     33
# 1852                    -32                     12
# 1855                     12                     60
# 1882                    -46                     67
# 1898                     34                     43
# 1900                     12                     32
# 1924                     15                     67
# 1940                     24                     45
# 1955                    -55                     37
# 1958                     15                     32
# 1963                    -21                     11
# 1965                     71                    117
# 1973                    -58                     12
#
# [230 rows x 18 columns]

# %%
# Get the number of candates appearing after pronoun, but still are the True coreference
temp_a = train.index[((train['A-pronoun-offset-diff'] > 0) == True) 
                     & (train['A-coref'] == True)].tolist() # Candidate A
temp_b = train.index[((train['B-pronoun-offset-diff'] > 0) == True) 
                     & (train['B-coref'] == True)].tolist() # candiate B
print(len(temp_a), len(temp_b))
# Out:
# 123 230

# %%
# Get the number of candates appearing after pronoun, and are False coreference
temp_a = train.index[((train['A-pronoun-offset-diff'] > 0) == True) 
                     & (train['A-coref'] == False)].tolist() # Candidate A
temp_b = train.index[((train['B-pronoun-offset-diff'] > 0) == True) 
                     & (train['B-coref'] == False)].tolist() # candiate B
print(len(temp_a), len(temp_b))
# Out:
# 151 266

# %%
# Get the numbers of the sentences where the pronoun, A and B are located in text
# Need to optimize the store_sentence_number() function

def get_sentence_number(sentences, offset):
    '''
    Get the number the sentence where the token is located.
    '''
    l = 0
    for i, sentence in enumerate(sentences):
        l += len(sentence) + 1
        if l >= offset:
            return i

def store_sentence_number(df):
    '''
    Store the number of the sentences where the pronun, A and B are located in text.
    '''
    
    for i, text in enumerate(df.Text):
        l1 = len(text)
        p_offset, a_offset, b_offset = df['Pronoun-offset'][i], \
                                        df['A-offset'][i], df['B-offset'][i]
        p = df['Pronoun'][i]

        doc = nlp(text)
        sentences = [sent.string.strip() for sent in doc.sents] # Splitting into sentences
        p_pos, a_pos, b_pos = None, None, None 
        
        df.at[i, 'Pronoun-sentence-number'] = get_sentence_number(sentences, p_offset)
        df.at[i, 'A-sentence-number'] = get_sentence_number(sentences, a_offset)
        df.at[i, 'B-sentence-number'] = get_sentence_number(sentences, b_offset)
        
    return


    
store_sentence_number(train)
store_sentence_number(valid)
store_sentence_number(test)

# %%
# Get number of FinalPro, MedialPro and InitialPro sample count
def extraction_pattern(df):
    if (df['A-sentence-number'] == df['B-sentence-number']) & \
        ((df['Pronoun-sentence-number'] == df['A-sentence-number']) | \
            (df['Pronoun-sentence-number'] == df['A-sentence-number'] + 1 )):
                return 'FinalPro'
    elif (df['Pronoun-sentence-number'] == df['A-sentence-number'] + 1) & \
        (df['Pronoun-sentence-number'] == df['B-sentence-number']):
                return 'MedialPro'
    elif (df['Pronoun-sentence-number'] == df['A-sentence-number']) & \
            df['A-sentence-number'] == df['B-sentence-number']:
                return 'InitialPro'

train['Extraction-pattern'] = df.apply(extraction_pattern, axis=1)
valid['Extraction-pattern'] = df.apply(extraction_pattern, axis=1)
test['Extraction-pattern'] = df.apply(extraction_pattern, axis=1)

def extraction_pattern_count(df):
    return len(df.index[df['Extraction-pattern'] == 'FinalPro']), \
            len(df.index[df['Extraction-pattern'] == 'MedialPro']), \
            len(df.index[df['Extraction-pattern'] == 'InitialPro'])

print(extraction_pattern_count(train))
print(extraction_pattern_count(valid))
print(extraction_pattern_count(test))
# Out:
# (1272, 539, 8)
# (294, 117, 2)
# (1272, 539, 8)

# %%
# Number of pronouns in each text? - Done
# How many person names in each text? - Done
# How close are other pronouns to the target pronoun?
# How close are the target nouns to the target pronoun? What about the ommitted nouns? - Partially done
# How many nouns and pronouns in the preceding, same, and trailing sentence?
# Position of actual name reference (immediate before, or appeared before another name.) 
# If there are two pronouns in the same sentence containing the target pronoun, are they both of the same gender?
# How many target pronouns are the first word in the sentence? - Done
# Get number of FinalPro, MedialPro and InitialPro sample count - Done

# %%
type(train.columns.values)
# Out:
# numpy.ndarray

# %%
# Displays the documentation for filter function
help(feature_names)
# Obtains the string of the documentation.
docstring = feature_names.__doc__
# Out:
# Help on function feature_names in module __main__:
#
# feature_names(df)
#     Get names of features.
#
#     :param df: A Pandas dataframe
#     :type df: pandas.core.frame.DataFrame
#     :return: List of column names in a Pandas dataframe
#     :rtype: numpy.ndarray

# %%
def foo():
    return

print(foo())
# Out:
# None
